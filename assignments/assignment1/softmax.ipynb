# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'Colab Notebooks/cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/cs231n/assignments/assignment1/cs231n/datasets
# /content/drive/My Drive/Colab Notebooks/cs231n/assignments/assignment1

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.359990
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.
#
# $\color{blue}{\textit Your Answer:}$
#
# *For now, the probability that correct class has the highest score is close to o.1.*
#
# *loss of softmax put -log() to the value.*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 2.159573 analytic: 2.159573, relative error: 8.807517e-09
# numerical: 1.865541 analytic: 1.865541, relative error: 4.584611e-08
# numerical: 1.449025 analytic: 1.449025, relative error: 1.571977e-08
# numerical: 0.052045 analytic: 0.052045, relative error: 6.546523e-07
# numerical: -0.197390 analytic: -0.197390, relative error: 3.377493e-08
# numerical: 4.991188 analytic: 4.991188, relative error: 3.153453e-08
# numerical: 0.230371 analytic: 0.230370, relative error: 4.407295e-07
# numerical: 1.117874 analytic: 1.117874, relative error: 6.295663e-08
# numerical: 0.388552 analytic: 0.388552, relative error: 3.611951e-08
# numerical: -0.652925 analytic: -0.652925, relative error: 4.593531e-08
# numerical: -0.712145 analytic: -0.712145, relative error: 1.147391e-07
# numerical: -1.372220 analytic: -1.372220, relative error: 3.251166e-08
# numerical: -5.906018 analytic: -5.906018, relative error: 3.515139e-09
# numerical: -2.238735 analytic: -2.238735, relative error: 2.792215e-08
# numerical: 1.984535 analytic: 1.984535, relative error: 2.772549e-09
# numerical: -0.769287 analytic: -0.769287, relative error: 2.394805e-08
# numerical: 0.078773 analytic: 0.078773, relative error: 2.934550e-07
# numerical: 1.219008 analytic: 1.219008, relative error: 3.418573e-08
# numerical: -2.389020 analytic: -2.389020, relative error: 2.884890e-09
# numerical: -1.012302 analytic: -1.012302, relative error: 4.258263e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.359990e+00 computed in 0.127810s
# vectorized loss: 2.359990e+00 computed in 0.012595s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the softmax; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [1.5e-7, 3.5e-7]
regularization_strengths = [2.3e4, 2.7e4]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


num_iters = 500
#from cs231n.classifiers import Softmax
learning_len = 10
regularization_len = 10

learning_rates_list = np.linspace(learning_rates[0], learning_rates[1], learning_len)
regularization_strengths_list = np.linspace(regularization_strengths[0], regularization_strengths[1], regularization_len)

for learning_idx ,learning_rate in enumerate(learning_rates_list):
  for regularization_idx, regularization_strength in enumerate(regularization_strengths_list):
    # initialize new Softmax object
    print("{} out of {}".format((learning_idx+1,regularization_idx+1), (learning_len,regularization_len)))
    softmax = Softmax()
    
    #train it with given hyperparameters
    softmax.train(X_train, y_train, learning_rate=learning_rate, reg=regularization_strength,
                        num_iters=num_iters, verbose=True)
    
    # predict with the trained softmax, then calculate accuracy
    y_train_pred = softmax.predict(X_train)
    y_val_pred = softmax.predict(X_val)
    
    # add result to results
    result_key = (learning_rate, regularization_strength)
    
    (training_accuracy, validation_accuracy) = (np.mean(y_train == y_train_pred), np.mean(y_val == y_val_pred))
    result_value = (training_accuracy, validation_accuracy)
    
    results[result_key] = result_value

    # find the best softmax with the highest validation accuracy
    if best_val < validation_accuracy:
      best_softmax = softmax
      best_val = validation_accuracy

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# (1, 1) out of (10, 10)
# iteration 0 / 500: loss 717.215017
# iteration 100 / 500: loss 180.090873
# iteration 200 / 500: loss 46.448731
# iteration 300 / 500: loss 13.118505
# iteration 400 / 500: loss 4.838897
# (1, 2) out of (10, 10)
# iteration 0 / 500: loss 730.923699
# iteration 100 / 500: loss 178.830864
# iteration 200 / 500: loss 45.031989
# iteration 300 / 500: loss 12.532372
# iteration 400 / 500: loss 4.625790
# (1, 3) out of (10, 10)
# iteration 0 / 500: loss 734.363847
# iteration 100 / 500: loss 174.851965
# iteration 200 / 500: loss 42.912149
# iteration 300 / 500: loss 11.703879
# iteration 400 / 500: loss 4.390250
# (1, 4) out of (10, 10)
# iteration 0 / 500: loss 768.871244
# iteration 100 / 500: loss 177.805875
# iteration 200 / 500: loss 42.509876
# iteration 300 / 500: loss 11.413319
# iteration 400 / 500: loss 4.261085
# (1, 5) out of (10, 10)
# iteration 0 / 500: loss 762.727480
# iteration 100 / 500: loss 172.157416
# iteration 200 / 500: loss 40.230456
# iteration 300 / 500: loss 10.594466
# iteration 400 / 500: loss 4.073975
# (1, 6) out of (10, 10)
# iteration 0 / 500: loss 787.754045
# iteration 100 / 500: loss 173.273715
# iteration 200 / 500: loss 39.442844
# iteration 300 / 500: loss 10.236205
# iteration 400 / 500: loss 3.879385
# (1, 7) out of (10, 10)
# iteration 0 / 500: loss 792.833715
# iteration 100 / 500: loss 169.556893
# iteration 200 / 500: loss 37.632082
# iteration 300 / 500: loss 9.623913
# iteration 400 / 500: loss 3.696349
# (1, 8) out of (10, 10)
# iteration 0 / 500: loss 797.012374
# iteration 100 / 500: loss 166.354413
# iteration 200 / 500: loss 36.027699
# iteration 300 / 500: loss 9.079730
# iteration 400 / 500: loss 3.563573
# (1, 9) out of (10, 10)
# iteration 0 / 500: loss 821.246630
# iteration 100 / 500: loss 166.649861
# iteration 200 / 500: loss 35.200754
# iteration 300 / 500: loss 8.765590
# iteration 400 / 500: loss 3.452201
# (1, 10) out of (10, 10)
# iteration 0 / 500: loss 842.543591
# iteration 100 / 500: loss 166.245233
# iteration 200 / 500: loss 34.232211
# iteration 300 / 500: loss 8.455390
# iteration 400 / 500: loss 3.376201
# (2, 1) out of (10, 10)
# iteration 0 / 500: loss 709.102635
# iteration 100 / 500: loss 145.042591
# iteration 200 / 500: loss 31.064671
# iteration 300 / 500: loss 7.922394
# iteration 400 / 500: loss 3.271347
# (2, 2) out of (10, 10)
# iteration 0 / 500: loss 729.686168
# iteration 100 / 500: loss 144.751440
# iteration 200 / 500: loss 30.150961
# iteration 300 / 500: loss 7.638359
# iteration 400 / 500: loss 3.164443
# (2, 3) out of (10, 10)
# iteration 0 / 500: loss 747.788575
# iteration 100 / 500: loss 143.873435
# iteration 200 / 500: loss 29.083360
# iteration 300 / 500: loss 7.249065
# iteration 400 / 500: loss 3.053984
# (2, 4) out of (10, 10)
# iteration 0 / 500: loss 754.118317
# iteration 100 / 500: loss 140.757846
# iteration 200 / 500: loss 27.729945
# iteration 300 / 500: loss 6.841617
# iteration 400 / 500: loss 2.951703
# (2, 5) out of (10, 10)
# iteration 0 / 500: loss 769.276468
# iteration 100 / 500: loss 139.334269
# iteration 200 / 500: loss 26.628075
# iteration 300 / 500: loss 6.534995
# iteration 400 / 500: loss 2.871745
# (2, 6) out of (10, 10)
# iteration 0 / 500: loss 772.813401
# iteration 100 / 500: loss 135.893039
# iteration 200 / 500: loss 25.311115
# iteration 300 / 500: loss 6.114884
# iteration 400 / 500: loss 2.816055
# (2, 7) out of (10, 10)
# iteration 0 / 500: loss 800.183860
# iteration 100 / 500: loss 136.171053
# iteration 200 / 500: loss 24.732545
# iteration 300 / 500: loss 5.908188
# iteration 400 / 500: loss 2.727940
# (2, 8) out of (10, 10)
# iteration 0 / 500: loss 807.108482
# iteration 100 / 500: loss 133.458364
# iteration 200 / 500: loss 23.482264
# iteration 300 / 500: loss 5.551580
# iteration 400 / 500: loss 2.662177
# (2, 9) out of (10, 10)
# iteration 0 / 500: loss 820.483976
# iteration 100 / 500: loss 131.402150
# iteration 200 / 500: loss 22.520584
# iteration 300 / 500: loss 5.242008
# iteration 400 / 500: loss 2.588752
# (2, 10) out of (10, 10)
# iteration 0 / 500: loss 848.093694
# iteration 100 / 500: loss 131.944304
# iteration 200 / 500: loss 22.080708
# iteration 300 / 500: loss 5.121860
# iteration 400 / 500: loss 2.604191
# (3, 1) out of (10, 10)
# iteration 0 / 500: loss 716.257101
# iteration 100 / 500: loss 119.459954
# iteration 200 / 500: loss 21.473342
# iteration 300 / 500: loss 5.274761
# iteration 400 / 500: loss 2.646413
# (3, 2) out of (10, 10)
# iteration 0 / 500: loss 721.504538
# iteration 100 / 500: loss 116.293044
# iteration 200 / 500: loss 20.345248
# iteration 300 / 500: loss 5.009563
# iteration 400 / 500: loss 2.523663
# (3, 3) out of (10, 10)
# iteration 0 / 500: loss 742.644440
# iteration 100 / 500: loss 115.811847
# iteration 200 / 500: loss 19.563323
# iteration 300 / 500: loss 4.741345
# iteration 400 / 500: loss 2.469521
# (3, 4) out of (10, 10)
# iteration 0 / 500: loss 753.632092
# iteration 100 / 500: loss 113.365031
# iteration 200 / 500: loss 18.649957
# iteration 300 / 500: loss 4.596816
# iteration 400 / 500: loss 2.470367
# (3, 5) out of (10, 10)
# iteration 0 / 500: loss 763.077643
# iteration 100 / 500: loss 111.136424
# iteration 200 / 500: loss 17.691614
# iteration 300 / 500: loss 4.342582
# iteration 400 / 500: loss 2.423233
# (3, 6) out of (10, 10)
# iteration 0 / 500: loss 788.314214
# iteration 100 / 500: loss 110.760630
# iteration 200 / 500: loss 17.100220
# iteration 300 / 500: loss 4.175359
# iteration 400 / 500: loss 2.414372
# (3, 7) out of (10, 10)
# iteration 0 / 500: loss 802.352896
# iteration 100 / 500: loss 108.934569
# iteration 200 / 500: loss 16.423090
# iteration 300 / 500: loss 3.968182
# iteration 400 / 500: loss 2.335358
# (3, 8) out of (10, 10)
# iteration 0 / 500: loss 812.456301
# iteration 100 / 500: loss 106.506200
# iteration 200 / 500: loss 15.570120
# iteration 300 / 500: loss 3.797596
# iteration 400 / 500: loss 2.267344
# (3, 9) out of (10, 10)
# iteration 0 / 500: loss 813.236611
# iteration 100 / 500: loss 103.178100
# iteration 200 / 500: loss 14.656979
# iteration 300 / 500: loss 3.691663
# iteration 400 / 500: loss 2.253957
# (3, 10) out of (10, 10)
# iteration 0 / 500: loss 833.253766
# iteration 100 / 500: loss 101.884820
# iteration 200 / 500: loss 14.130988
# iteration 300 / 500: loss 3.559500
# iteration 400 / 500: loss 2.241576
# (4, 1) out of (10, 10)
# iteration 0 / 500: loss 719.061233
# iteration 100 / 500: loss 98.096802
# iteration 200 / 500: loss 15.013650
# iteration 300 / 500: loss 3.845136
# iteration 400 / 500: loss 2.276456
# (4, 2) out of (10, 10)
# iteration 0 / 500: loss 720.849297
# iteration 100 / 500: loss 94.683855
# iteration 200 / 500: loss 14.061761
# iteration 300 / 500: loss 3.652523
# iteration 400 / 500: loss 2.288525
# (4, 3) out of (10, 10)
# iteration 0 / 500: loss 739.556676
# iteration 100 / 500: loss 93.277179
# iteration 200 / 500: loss 13.386416
# iteration 300 / 500: loss 3.500870
# iteration 400 / 500: loss 2.253301
# (4, 4) out of (10, 10)
# iteration 0 / 500: loss 755.615758
# iteration 100 / 500: loss 91.707887
# iteration 200 / 500: loss 12.777498
# iteration 300 / 500: loss 3.286107
# iteration 400 / 500: loss 2.247611
# (4, 5) out of (10, 10)
# iteration 0 / 500: loss 770.223744
# iteration 100 / 500: loss 90.108164
# iteration 200 / 500: loss 12.107176
# iteration 300 / 500: loss 3.258320
# iteration 400 / 500: loss 2.248881
# (4, 6) out of (10, 10)
# iteration 0 / 500: loss 780.152921
# iteration 100 / 500: loss 87.781296
# iteration 200 / 500: loss 11.516948
# iteration 300 / 500: loss 3.163846
# iteration 400 / 500: loss 2.214106
# (4, 7) out of (10, 10)
# iteration 0 / 500: loss 783.458164
# iteration 100 / 500: loss 85.000901
# iteration 200 / 500: loss 10.838244
# iteration 300 / 500: loss 2.989310
# iteration 400 / 500: loss 2.206595
# (4, 8) out of (10, 10)
# iteration 0 / 500: loss 808.546868
# iteration 100 / 500: loss 84.383722
# iteration 200 / 500: loss 10.510708
# iteration 300 / 500: loss 2.932239
# iteration 400 / 500: loss 2.231803
# (4, 9) out of (10, 10)
# iteration 0 / 500: loss 824.803837
# iteration 100 / 500: loss 82.698624
# iteration 200 / 500: loss 10.022447
# iteration 300 / 500: loss 2.913646
# iteration 400 / 500: loss 2.182157
# (4, 10) out of (10, 10)
# iteration 0 / 500: loss 828.767294
# iteration 100 / 500: loss 79.932722
# iteration 200 / 500: loss 9.497169
# iteration 300 / 500: loss 2.787109
# iteration 400 / 500: loss 2.183055
# (5, 1) out of (10, 10)
# iteration 0 / 500: loss 701.953382
# iteration 100 / 500: loss 78.147871
# iteration 200 / 500: loss 10.388042
# iteration 300 / 500: loss 2.945431
# iteration 400 / 500: loss 2.198488
# (5, 2) out of (10, 10)
# iteration 0 / 500: loss 736.268754
# iteration 100 / 500: loss 78.542539
# iteration 200 / 500: loss 10.094829
# iteration 300 / 500: loss 2.938138
# iteration 400 / 500: loss 2.131842
# (5, 3) out of (10, 10)
# iteration 0 / 500: loss 741.311239
# iteration 100 / 500: loss 75.833920
# iteration 200 / 500: loss 9.465204
# iteration 300 / 500: loss 2.878324
# iteration 400 / 500: loss 2.165832
# (5, 4) out of (10, 10)
# iteration 0 / 500: loss 756.443963
# iteration 100 / 500: loss 74.117245
# iteration 200 / 500: loss 9.011673
# iteration 300 / 500: loss 2.779484
# iteration 400 / 500: loss 2.097233
# (5, 5) out of (10, 10)
# iteration 0 / 500: loss 765.271666
# iteration 100 / 500: loss 71.969212
# iteration 200 / 500: loss 8.500295
# iteration 300 / 500: loss 2.723475
# iteration 400 / 500: loss 2.116800
# (5, 6) out of (10, 10)
# iteration 0 / 500: loss 770.135929
# iteration 100 / 500: loss 69.378411
# iteration 200 / 500: loss 8.012536
# iteration 300 / 500: loss 2.586675
# iteration 400 / 500: loss 2.148138
# (5, 7) out of (10, 10)
# iteration 0 / 500: loss 793.036679
# iteration 100 / 500: loss 68.575947
# iteration 200 / 500: loss 7.689397
# iteration 300 / 500: loss 2.628264
# iteration 400 / 500: loss 2.109774
# (5, 8) out of (10, 10)
# iteration 0 / 500: loss 808.580951
# iteration 100 / 500: loss 67.130814
# iteration 200 / 500: loss 7.276073
# iteration 300 / 500: loss 2.517867
# iteration 400 / 500: loss 2.083824
# (5, 9) out of (10, 10)
# iteration 0 / 500: loss 815.921016
# iteration 100 / 500: loss 64.871897
# iteration 200 / 500: loss 6.935589
# iteration 300 / 500: loss 2.510582
# iteration 400 / 500: loss 2.161625
# (5, 10) out of (10, 10)
# iteration 0 / 500: loss 830.930943
# iteration 100 / 500: loss 63.334800
# iteration 200 / 500: loss 6.675279
# iteration 300 / 500: loss 2.471025
# iteration 400 / 500: loss 2.095409
# (6, 1) out of (10, 10)
# iteration 0 / 500: loss 715.549429
# iteration 100 / 500: loss 64.965025
# iteration 200 / 500: loss 7.703626
# iteration 300 / 500: loss 2.527913
# iteration 400 / 500: loss 2.091072
# (6, 2) out of (10, 10)
# iteration 0 / 500: loss 729.581483
# iteration 100 / 500: loss 63.416028
# iteration 200 / 500: loss 7.317570
# iteration 300 / 500: loss 2.524436
# iteration 400 / 500: loss 2.161633
# (6, 3) out of (10, 10)
# iteration 0 / 500: loss 746.494433
# iteration 100 / 500: loss 61.989648
# iteration 200 / 500: loss 6.930077
# iteration 300 / 500: loss 2.502021
# iteration 400 / 500: loss 2.127152
# (6, 4) out of (10, 10)
# iteration 0 / 500: loss 755.771029
# iteration 100 / 500: loss 59.977695
# iteration 200 / 500: loss 6.563495
# iteration 300 / 500: loss 2.405595
# iteration 400 / 500: loss 2.087341
# (6, 5) out of (10, 10)
# iteration 0 / 500: loss 780.649280
# iteration 100 / 500: loss 59.031701
# iteration 200 / 500: loss 6.228353
# iteration 300 / 500: loss 2.393022
# iteration 400 / 500: loss 2.120284
# (6, 6) out of (10, 10)
# iteration 0 / 500: loss 783.330349
# iteration 100 / 500: loss 56.687882
# iteration 200 / 500: loss 5.903908
# iteration 300 / 500: loss 2.370558
# iteration 400 / 500: loss 2.134206
# (6, 7) out of (10, 10)
# iteration 0 / 500: loss 791.775534
# iteration 100 / 500: loss 54.701257
# iteration 200 / 500: loss 5.631947
# iteration 300 / 500: loss 2.335028
# iteration 400 / 500: loss 2.045079
# (6, 8) out of (10, 10)
# iteration 0 / 500: loss 798.318229
# iteration 100 / 500: loss 52.768007
# iteration 200 / 500: loss 5.338389
# iteration 300 / 500: loss 2.285882
# iteration 400 / 500: loss 2.127180
# (6, 9) out of (10, 10)
# iteration 0 / 500: loss 835.081108
# iteration 100 / 500: loss 52.748412
# iteration 200 / 500: loss 5.215809
# iteration 300 / 500: loss 2.239582
# iteration 400 / 500: loss 2.100470
# (6, 10) out of (10, 10)
# iteration 0 / 500: loss 844.581273
# iteration 100 / 500: loss 50.773120
# iteration 200 / 500: loss 4.946518
# iteration 300 / 500: loss 2.319950
# iteration 400 / 500: loss 2.147221
# (7, 1) out of (10, 10)
# iteration 0 / 500: loss 708.574404
# iteration 100 / 500: loss 52.817769
# iteration 200 / 500: loss 5.699268
# iteration 300 / 500: loss 2.347079
# iteration 400 / 500: loss 2.108331
# (7, 2) out of (10, 10)
# iteration 0 / 500: loss 736.675674
# iteration 100 / 500: loss 52.152515
# iteration 200 / 500: loss 5.533561
# iteration 300 / 500: loss 2.323222
# iteration 400 / 500: loss 2.050784
# (7, 3) out of (10, 10)
# iteration 0 / 500: loss 736.880622
# iteration 100 / 500: loss 49.711594
# iteration 200 / 500: loss 5.215023
# iteration 300 / 500: loss 2.239833
# iteration 400 / 500: loss 2.152104
# (7, 4) out of (10, 10)
# iteration 0 / 500: loss 753.846114
# iteration 100 / 500: loss 48.355767
# iteration 200 / 500: loss 4.967182
# iteration 300 / 500: loss 2.245437
# iteration 400 / 500: loss 2.078769
# (7, 5) out of (10, 10)
# iteration 0 / 500: loss 758.852815
# iteration 100 / 500: loss 46.363179
# iteration 200 / 500: loss 4.722452
# iteration 300 / 500: loss 2.223998
# iteration 400 / 500: loss 2.098398
# (7, 6) out of (10, 10)
# iteration 0 / 500: loss 778.987369
# iteration 100 / 500: loss 45.230693
# iteration 200 / 500: loss 4.488051
# iteration 300 / 500: loss 2.257815
# iteration 400 / 500: loss 2.076933
# (7, 7) out of (10, 10)
# iteration 0 / 500: loss 798.184630
# iteration 100 / 500: loss 44.012011
# iteration 200 / 500: loss 4.263477
# iteration 300 / 500: loss 2.234421
# iteration 400 / 500: loss 2.063714
# (7, 8) out of (10, 10)
# iteration 0 / 500: loss 798.466581
# iteration 100 / 500: loss 42.136994
# iteration 200 / 500: loss 4.092977
# iteration 300 / 500: loss 2.207418
# iteration 400 / 500: loss 2.089390
# (7, 9) out of (10, 10)
# iteration 0 / 500: loss 817.195101
# iteration 100 / 500: loss 41.067632
# iteration 200 / 500: loss 3.982430
# iteration 300 / 500: loss 2.151552
# iteration 400 / 500: loss 2.111914
# (7, 10) out of (10, 10)
# iteration 0 / 500: loss 825.898021
# iteration 100 / 500: loss 39.476255
# iteration 200 / 500: loss 3.835727
# iteration 300 / 500: loss 2.186876
# iteration 400 / 500: loss 2.064338
# (8, 1) out of (10, 10)
# iteration 0 / 500: loss 720.344102
# iteration 100 / 500: loss 43.918560
# iteration 200 / 500: loss 4.555302
# iteration 300 / 500: loss 2.230588
# iteration 400 / 500: loss 2.062851
# (8, 2) out of (10, 10)
# iteration 0 / 500: loss 723.153545
# iteration 100 / 500: loss 41.854685
# iteration 200 / 500: loss 4.263480
# iteration 300 / 500: loss 2.178638
# iteration 400 / 500: loss 2.101363
# (8, 3) out of (10, 10)
# iteration 0 / 500: loss 733.229036
# iteration 100 / 500: loss 40.207192
# iteration 200 / 500: loss 4.125351
# iteration 300 / 500: loss 2.146301
# iteration 400 / 500: loss 2.121177
# (8, 4) out of (10, 10)
# iteration 0 / 500: loss 756.996718
# iteration 100 / 500: loss 39.314374
# iteration 200 / 500: loss 3.912883
# iteration 300 / 500: loss 2.192724
# iteration 400 / 500: loss 2.095790
# (8, 5) out of (10, 10)
# iteration 0 / 500: loss 761.112931
# iteration 100 / 500: loss 37.664155
# iteration 200 / 500: loss 3.737649
# iteration 300 / 500: loss 2.144632
# iteration 400 / 500: loss 2.078138
# (8, 6) out of (10, 10)
# iteration 0 / 500: loss 782.052590
# iteration 100 / 500: loss 36.674720
# iteration 200 / 500: loss 3.610209
# iteration 300 / 500: loss 2.213061
# iteration 400 / 500: loss 2.089343
# (8, 7) out of (10, 10)
# iteration 0 / 500: loss 794.218228
# iteration 100 / 500: loss 35.315701
# iteration 200 / 500: loss 3.538152
# iteration 300 / 500: loss 2.145692
# iteration 400 / 500: loss 2.080735
# (8, 8) out of (10, 10)
# iteration 0 / 500: loss 813.574638
# iteration 100 / 500: loss 34.216294
# iteration 200 / 500: loss 3.404875
# iteration 300 / 500: loss 2.177267
# iteration 400 / 500: loss 2.076485
# (8, 9) out of (10, 10)
# iteration 0 / 500: loss 823.969981
# iteration 100 / 500: loss 32.886092
# iteration 200 / 500: loss 3.268015
# iteration 300 / 500: loss 2.200549
# iteration 400 / 500: loss 2.102797
# (8, 10) out of (10, 10)
# iteration 0 / 500: loss 828.552422
# iteration 100 / 500: loss 31.418586
# iteration 200 / 500: loss 3.105752
# iteration 300 / 500: loss 2.150205
# iteration 400 / 500: loss 2.071286
# (9, 1) out of (10, 10)
# iteration 0 / 500: loss 711.980863
# iteration 100 / 500: loss 35.749657
# iteration 200 / 500: loss 3.665068
# iteration 300 / 500: loss 2.164260
# iteration 400 / 500: loss 2.051727
# (9, 2) out of (10, 10)
# iteration 0 / 500: loss 723.031781
# iteration 100 / 500: loss 34.328610
# iteration 200 / 500: loss 3.485831
# iteration 300 / 500: loss 2.129819
# iteration 400 / 500: loss 2.102633
# (9, 3) out of (10, 10)
# iteration 0 / 500: loss 731.591397
# iteration 100 / 500: loss 32.798239
# iteration 200 / 500: loss 3.384749
# iteration 300 / 500: loss 2.182517
# iteration 400 / 500: loss 2.017054
# (9, 4) out of (10, 10)
# iteration 0 / 500: loss 750.535665
# iteration 100 / 500: loss 31.754144
# iteration 200 / 500: loss 3.240261
# iteration 300 / 500: loss 2.108500
# iteration 400 / 500: loss 2.119306
# (9, 5) out of (10, 10)
# iteration 0 / 500: loss 760.391582
# iteration 100 / 500: loss 30.532779
# iteration 200 / 500: loss 3.212689
# iteration 300 / 500: loss 2.105825
# iteration 400 / 500: loss 2.061610
# (9, 6) out of (10, 10)
# iteration 0 / 500: loss 781.967492
# iteration 100 / 500: loss 29.569746
# iteration 200 / 500: loss 3.115420
# iteration 300 / 500: loss 2.059764
# iteration 400 / 500: loss 2.082522
# (9, 7) out of (10, 10)
# iteration 0 / 500: loss 796.433771
# iteration 100 / 500: loss 28.482610
# iteration 200 / 500: loss 2.950961
# iteration 300 / 500: loss 2.151666
# iteration 400 / 500: loss 2.110106
# (9, 8) out of (10, 10)
# iteration 0 / 500: loss 813.847261
# iteration 100 / 500: loss 27.501258
# iteration 200 / 500: loss 2.861414
# iteration 300 / 500: loss 2.098997
# iteration 400 / 500: loss 2.116934
# (9, 9) out of (10, 10)
# iteration 0 / 500: loss 825.655664
# iteration 100 / 500: loss 26.325513
# iteration 200 / 500: loss 2.807201
# iteration 300 / 500: loss 2.111879
# iteration 400 / 500: loss 2.096728
# (9, 10) out of (10, 10)
# iteration 0 / 500: loss 832.975874
# iteration 100 / 500: loss 25.057222
# iteration 200 / 500: loss 2.693530
# iteration 300 / 500: loss 2.106111
# iteration 400 / 500: loss 2.072642
# (10, 1) out of (10, 10)
# iteration 0 / 500: loss 713.628569
# iteration 100 / 500: loss 29.399981
# iteration 200 / 500: loss 3.174801
# iteration 300 / 500: loss 2.043726
# iteration 400 / 500: loss 2.031118
# (10, 2) out of (10, 10)
# iteration 0 / 500: loss 743.892367
# iteration 100 / 500: loss 28.867650
# iteration 200 / 500: loss 3.004484
# iteration 300 / 500: loss 2.109911
# iteration 400 / 500: loss 2.111348
# (10, 3) out of (10, 10)
# iteration 0 / 500: loss 735.180410
# iteration 100 / 500: loss 26.999282
# iteration 200 / 500: loss 2.886559
# iteration 300 / 500: loss 2.109001
# iteration 400 / 500: loss 2.074150
# (10, 4) out of (10, 10)
# iteration 0 / 500: loss 756.378195
# iteration 100 / 500: loss 26.080328
# iteration 200 / 500: loss 2.904665
# iteration 300 / 500: loss 2.137510
# iteration 400 / 500: loss 2.044366
# (10, 5) out of (10, 10)
# iteration 0 / 500: loss 771.904467
# iteration 100 / 500: loss 25.027433
# iteration 200 / 500: loss 2.759368
# iteration 300 / 500: loss 2.131111
# iteration 400 / 500: loss 2.114783
# (10, 6) out of (10, 10)
# iteration 0 / 500: loss 774.761078
# iteration 100 / 500: loss 23.791235
# iteration 200 / 500: loss 2.661078
# iteration 300 / 500: loss 2.092971
# iteration 400 / 500: loss 2.133940
# (10, 7) out of (10, 10)
# iteration 0 / 500: loss 797.976264
# iteration 100 / 500: loss 23.020521
# iteration 200 / 500: loss 2.638506
# iteration 300 / 500: loss 2.098342
# iteration 400 / 500: loss 2.052794
# (10, 8) out of (10, 10)
# iteration 0 / 500: loss 810.317930
# iteration 100 / 500: loss 21.996064
# iteration 200 / 500: loss 2.593111
# iteration 300 / 500: loss 2.118319
# iteration 400 / 500: loss 2.067236
# (10, 9) out of (10, 10)
# iteration 0 / 500: loss 832.922319
# iteration 100 / 500: loss 21.381197
# iteration 200 / 500: loss 2.527811
# iteration 300 / 500: loss 2.139898
# iteration 400 / 500: loss 2.146575
# (10, 10) out of (10, 10)
# iteration 0 / 500: loss 820.656007
# iteration 100 / 500: loss 19.872346
# iteration 200 / 500: loss 2.455950
# iteration 300 / 500: loss 2.130291
# iteration 400 / 500: loss 2.072239
# lr 1.500000e-07 reg 2.300000e+04 train accuracy: 0.323143 val accuracy: 0.336000
# lr 1.500000e-07 reg 2.344444e+04 train accuracy: 0.331980 val accuracy: 0.345000
# lr 1.500000e-07 reg 2.388889e+04 train accuracy: 0.329633 val accuracy: 0.327000
# lr 1.500000e-07 reg 2.433333e+04 train accuracy: 0.324143 val accuracy: 0.338000
# lr 1.500000e-07 reg 2.477778e+04 train accuracy: 0.331184 val accuracy: 0.357000
# lr 1.500000e-07 reg 2.522222e+04 train accuracy: 0.326939 val accuracy: 0.338000
# lr 1.500000e-07 reg 2.566667e+04 train accuracy: 0.325837 val accuracy: 0.347000
# lr 1.500000e-07 reg 2.611111e+04 train accuracy: 0.325184 val accuracy: 0.344000
# lr 1.500000e-07 reg 2.655556e+04 train accuracy: 0.327612 val accuracy: 0.340000
# lr 1.500000e-07 reg 2.700000e+04 train accuracy: 0.328245 val accuracy: 0.339000
# lr 1.722222e-07 reg 2.300000e+04 train accuracy: 0.324918 val accuracy: 0.340000
# lr 1.722222e-07 reg 2.344444e+04 train accuracy: 0.332265 val accuracy: 0.357000
# lr 1.722222e-07 reg 2.388889e+04 train accuracy: 0.326041 val accuracy: 0.342000
# lr 1.722222e-07 reg 2.433333e+04 train accuracy: 0.323388 val accuracy: 0.335000
# lr 1.722222e-07 reg 2.477778e+04 train accuracy: 0.330980 val accuracy: 0.345000
# lr 1.722222e-07 reg 2.522222e+04 train accuracy: 0.328857 val accuracy: 0.353000
# lr 1.722222e-07 reg 2.566667e+04 train accuracy: 0.326551 val accuracy: 0.345000
# lr 1.722222e-07 reg 2.611111e+04 train accuracy: 0.330041 val accuracy: 0.352000
# lr 1.722222e-07 reg 2.655556e+04 train accuracy: 0.326939 val accuracy: 0.335000
# lr 1.722222e-07 reg 2.700000e+04 train accuracy: 0.323510 val accuracy: 0.336000
# lr 1.944444e-07 reg 2.300000e+04 train accuracy: 0.337857 val accuracy: 0.351000
# lr 1.944444e-07 reg 2.344444e+04 train accuracy: 0.327347 val accuracy: 0.341000
# lr 1.944444e-07 reg 2.388889e+04 train accuracy: 0.330694 val accuracy: 0.345000
# lr 1.944444e-07 reg 2.433333e+04 train accuracy: 0.326776 val accuracy: 0.342000
# lr 1.944444e-07 reg 2.477778e+04 train accuracy: 0.332061 val accuracy: 0.348000
# lr 1.944444e-07 reg 2.522222e+04 train accuracy: 0.334510 val accuracy: 0.354000
# lr 1.944444e-07 reg 2.566667e+04 train accuracy: 0.319041 val accuracy: 0.334000
# lr 1.944444e-07 reg 2.611111e+04 train accuracy: 0.332020 val accuracy: 0.340000
# lr 1.944444e-07 reg 2.655556e+04 train accuracy: 0.328898 val accuracy: 0.342000
# lr 1.944444e-07 reg 2.700000e+04 train accuracy: 0.328939 val accuracy: 0.346000
# lr 2.166667e-07 reg 2.300000e+04 train accuracy: 0.335143 val accuracy: 0.351000
# lr 2.166667e-07 reg 2.344444e+04 train accuracy: 0.330510 val accuracy: 0.343000
# lr 2.166667e-07 reg 2.388889e+04 train accuracy: 0.332612 val accuracy: 0.345000
# lr 2.166667e-07 reg 2.433333e+04 train accuracy: 0.323367 val accuracy: 0.346000
# lr 2.166667e-07 reg 2.477778e+04 train accuracy: 0.332755 val accuracy: 0.350000
# lr 2.166667e-07 reg 2.522222e+04 train accuracy: 0.324653 val accuracy: 0.333000
# lr 2.166667e-07 reg 2.566667e+04 train accuracy: 0.331592 val accuracy: 0.351000
# lr 2.166667e-07 reg 2.611111e+04 train accuracy: 0.328959 val accuracy: 0.350000
# lr 2.166667e-07 reg 2.655556e+04 train accuracy: 0.323918 val accuracy: 0.339000
# lr 2.166667e-07 reg 2.700000e+04 train accuracy: 0.323163 val accuracy: 0.339000
# lr 2.388889e-07 reg 2.300000e+04 train accuracy: 0.327531 val accuracy: 0.343000
# lr 2.388889e-07 reg 2.344444e+04 train accuracy: 0.331388 val accuracy: 0.346000
# lr 2.388889e-07 reg 2.388889e+04 train accuracy: 0.337939 val accuracy: 0.352000
# lr 2.388889e-07 reg 2.433333e+04 train accuracy: 0.328122 val accuracy: 0.337000
# lr 2.388889e-07 reg 2.477778e+04 train accuracy: 0.324163 val accuracy: 0.347000
# lr 2.388889e-07 reg 2.522222e+04 train accuracy: 0.328143 val accuracy: 0.342000
# lr 2.388889e-07 reg 2.566667e+04 train accuracy: 0.322816 val accuracy: 0.346000
# lr 2.388889e-07 reg 2.611111e+04 train accuracy: 0.324755 val accuracy: 0.340000
# lr 2.388889e-07 reg 2.655556e+04 train accuracy: 0.335388 val accuracy: 0.349000
# lr 2.388889e-07 reg 2.700000e+04 train accuracy: 0.322020 val accuracy: 0.338000
# lr 2.611111e-07 reg 2.300000e+04 train accuracy: 0.332449 val accuracy: 0.333000
# lr 2.611111e-07 reg 2.344444e+04 train accuracy: 0.330041 val accuracy: 0.342000
# lr 2.611111e-07 reg 2.388889e+04 train accuracy: 0.332184 val accuracy: 0.349000
# lr 2.611111e-07 reg 2.433333e+04 train accuracy: 0.329694 val accuracy: 0.338000
# lr 2.611111e-07 reg 2.477778e+04 train accuracy: 0.328265 val accuracy: 0.338000
# lr 2.611111e-07 reg 2.522222e+04 train accuracy: 0.322633 val accuracy: 0.324000
# lr 2.611111e-07 reg 2.566667e+04 train accuracy: 0.328735 val accuracy: 0.348000
# lr 2.611111e-07 reg 2.611111e+04 train accuracy: 0.314939 val accuracy: 0.330000
# lr 2.611111e-07 reg 2.655556e+04 train accuracy: 0.321020 val accuracy: 0.337000
# lr 2.611111e-07 reg 2.700000e+04 train accuracy: 0.326592 val accuracy: 0.350000
# lr 2.833333e-07 reg 2.300000e+04 train accuracy: 0.333408 val accuracy: 0.343000
# lr 2.833333e-07 reg 2.344444e+04 train accuracy: 0.331857 val accuracy: 0.348000
# lr 2.833333e-07 reg 2.388889e+04 train accuracy: 0.324714 val accuracy: 0.339000
# lr 2.833333e-07 reg 2.433333e+04 train accuracy: 0.327224 val accuracy: 0.350000
# lr 2.833333e-07 reg 2.477778e+04 train accuracy: 0.329000 val accuracy: 0.335000
# lr 2.833333e-07 reg 2.522222e+04 train accuracy: 0.328367 val accuracy: 0.340000
# lr 2.833333e-07 reg 2.566667e+04 train accuracy: 0.331592 val accuracy: 0.336000
# lr 2.833333e-07 reg 2.611111e+04 train accuracy: 0.326041 val accuracy: 0.338000
# lr 2.833333e-07 reg 2.655556e+04 train accuracy: 0.326306 val accuracy: 0.339000
# lr 2.833333e-07 reg 2.700000e+04 train accuracy: 0.319388 val accuracy: 0.336000
# lr 3.055556e-07 reg 2.300000e+04 train accuracy: 0.333327 val accuracy: 0.336000
# lr 3.055556e-07 reg 2.344444e+04 train accuracy: 0.329020 val accuracy: 0.345000
# lr 3.055556e-07 reg 2.388889e+04 train accuracy: 0.321612 val accuracy: 0.340000
# lr 3.055556e-07 reg 2.433333e+04 train accuracy: 0.328796 val accuracy: 0.347000
# lr 3.055556e-07 reg 2.477778e+04 train accuracy: 0.325490 val accuracy: 0.336000
# lr 3.055556e-07 reg 2.522222e+04 train accuracy: 0.328000 val accuracy: 0.350000
# lr 3.055556e-07 reg 2.566667e+04 train accuracy: 0.315347 val accuracy: 0.332000
# lr 3.055556e-07 reg 2.611111e+04 train accuracy: 0.331490 val accuracy: 0.344000
# lr 3.055556e-07 reg 2.655556e+04 train accuracy: 0.325980 val accuracy: 0.330000
# lr 3.055556e-07 reg 2.700000e+04 train accuracy: 0.317776 val accuracy: 0.333000
# lr 3.277778e-07 reg 2.300000e+04 train accuracy: 0.334224 val accuracy: 0.351000
# lr 3.277778e-07 reg 2.344444e+04 train accuracy: 0.337959 val accuracy: 0.350000
# lr 3.277778e-07 reg 2.388889e+04 train accuracy: 0.325367 val accuracy: 0.331000
# lr 3.277778e-07 reg 2.433333e+04 train accuracy: 0.324020 val accuracy: 0.336000
# lr 3.277778e-07 reg 2.477778e+04 train accuracy: 0.325204 val accuracy: 0.340000
# lr 3.277778e-07 reg 2.522222e+04 train accuracy: 0.333735 val accuracy: 0.359000
# lr 3.277778e-07 reg 2.566667e+04 train accuracy: 0.326755 val accuracy: 0.342000
# lr 3.277778e-07 reg 2.611111e+04 train accuracy: 0.325755 val accuracy: 0.339000
# lr 3.277778e-07 reg 2.655556e+04 train accuracy: 0.330204 val accuracy: 0.347000
# lr 3.277778e-07 reg 2.700000e+04 train accuracy: 0.327837 val accuracy: 0.339000
# lr 3.500000e-07 reg 2.300000e+04 train accuracy: 0.325980 val accuracy: 0.335000
# lr 3.500000e-07 reg 2.344444e+04 train accuracy: 0.329918 val accuracy: 0.349000
# lr 3.500000e-07 reg 2.388889e+04 train accuracy: 0.321388 val accuracy: 0.334000
# lr 3.500000e-07 reg 2.433333e+04 train accuracy: 0.326306 val accuracy: 0.334000
# lr 3.500000e-07 reg 2.477778e+04 train accuracy: 0.330122 val accuracy: 0.335000
# lr 3.500000e-07 reg 2.522222e+04 train accuracy: 0.329531 val accuracy: 0.334000
# lr 3.500000e-07 reg 2.566667e+04 train accuracy: 0.325204 val accuracy: 0.342000
# lr 3.500000e-07 reg 2.611111e+04 train accuracy: 0.325939 val accuracy: 0.342000
# lr 3.500000e-07 reg 2.655556e+04 train accuracy: 0.334245 val accuracy: 0.343000
# lr 3.500000e-07 reg 2.700000e+04 train accuracy: 0.326224 val accuracy: 0.349000
# best validation accuracy achieved during cross-validation: 0.359000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.354000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$ *True*
#
#
#
# $\color{blue}{\textit Your Explanation:}$
#
# *For SVM classifer, adding appropriate datapoint which has high score on one class and low class on others, will be maxed-out by max function. This means loss will not be changed.*
#
# *For Softmax classifer, for any data point, probability cannot be 1 because it sums the exp values of score. This means loss will be changed.*

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
